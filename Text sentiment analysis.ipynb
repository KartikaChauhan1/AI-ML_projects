# %%
from textblob import TextBlob      #used beacuse it processes textual dataand provides API for NLP
from newspaper import Article

# %%
url='https://www.jagranjosh.com/articles/iit-jee-advanced-topper-2023-success-stories-1700566501-1'    #put up a link of the text you want to test the sentiment of 
article=Article(url)
article.download()
article.parse()    #analyses the grammatical sentences and their meaning
article.nlp()

# %%
import nltk     #it work with human language data
nltk.download('punkt')    #breaks text into smaller units and works with multiple languages
nltk.download('punkt', download_dir='/Users/kartikachauhan')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kartikachauhan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/kartikachauhan...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text=article.text
print(text)
# Out:
# A total of 11,13,325 candidates appeared for JEE Mains. Out of the total number of aspirants, 180372 students cleared the JEE Mains and 43773 candidates qualified for JEE Advanced 2023. In this article, we have mentioned everything about JEE Advanced Toppers 2023, including their marks, family background, dreams, and success mantra that have earned them a coveted position in IIT JEE Toppers List.
#
# iittJEE Advanced Toppers 2023: Vavilala Chidvilas Reddy of IIT Hyderabad zone bagged AIR rank 1 in JEE Advanced 2023 by scoring 341 out of 360 marks. He has opted for Computer Science Engineering from IIT Mumbai, one of the most favoured engineering colleges for IIT aspirants. Nayakanti Naga Bhavya Sree is the top-performing female candidate, achieving an impressive score of 298 marks and securing AIR 56.
#
# ...

# %%
blob=TextBlob(text)
sentiment=blob.sentiment.polarity    #-1 to 1
print(sentiment)
# Out:
# 0.1256084656084656
